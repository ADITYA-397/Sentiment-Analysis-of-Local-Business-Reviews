# %%
from textblob import TextBlob
import pandas as pd
import matplotlib.pyplot as plt

reviews = {
    "Lost Stories Academy": [
        "Did a 2 month beginner DJ course, and super glad i went with LSA after looking at all online offline options in mumbai. What stands out is that the course is very well thought out, and the faculty is excellent. Apart from the theory and practicals, a large part of the course also helps you in building your  brand and making sure you’ve the best chances to commercially dj - the alumini and the faculty helps you get gigs as well.This absolutely beats learning online in probably an unstructured manner.All in all, probably the only time in my life I looked forward to waking up at 9 am to travel to the class on Saturdays and sundays for two months straight.Highly recommended.",
        "Thank you Vedant and Mayank for your incredible guidance and support throughout our DJ training. Also thanks to Prayag sir for his inspiring session. Your passion for music and teaching made every session enjoyable. I will be doing my first gig on June 8, 2025. Many thanks once again. Cheers!",
        "Great learning experience! The mentors are super skilled and supportive. Perfect place to grow as a music producer.",
        "I’m a self taught producers and there was always few things which I lacked and I didn’t know what I needed to do so I joined LSA and I got to learn everything I lacked and realized there’s a lotto give to music than I thought. A year with LSA was one of the best year I had cause I learned everything related to music like how to Produce, mix and master, Music Business, Etc. It is not one of the best, it is THE BEST MUSIC ACADEMY IN INDIA."
        "Have done my gold course here, and i can't describe in words, how much knowledge I have gained throughout all sectors of the music industry. The faculty here is incredibly talented. It's undoubtedly the best music school for electronic music in India.",
        "I joined Lost stories academy in January 2024 For DJing  (two months course). I loved the process of learning the basics and the advanced mixing techniques in djing taught by Vedant Singh (LSA) faculty. It really motivated me to learn more and know how to connect with your audience on stage. As I finished my course I also saw how the music production students were excellent in producing their own songs and that feeling made me join for music prodigy as well. A huge thanks and very much grateful to have been learning from the best mentors Amey sir, Sanket sir, Aditya sir, Vedant sir  Anshuman,Sahil sir and Mayank vidhani(LSA faculty)very supportive and always pushing you to do great.very much grateful to be a student of the Lost stories academy. Thanks to Prayag Mehta sir and Rishab jyoshi sir from the (Lost stories)for starting such an academy where you get to take your creativity in music to the next level. I wouldn't only say it's the best but it's a great academy in India to learn djing and music production.",
        "i joined LSA in 2024 music prodigy course. loved the modules and and the way of teaching of the faculty. aditiya sir, sanket sir , amey sir gave me the best experience of music production. loved the vibe the of academy. if u want to learn music production , wanna be a singer , rapper , musician LSA is the right choice. u will get lot of opportunities and mentorship with many master classes.",
        "Love this play very good for djing and music production and also very supportive staff just love being LSA student.",
        "I Completed the music prodigy course today. Looking back it feels like i have learnt so much about both music and the industry around it. There’s no way i could have learnt this much without the guidance of the instructors at the academy. Really grateful for my year here and would 10/10 recommend this to anyone wanting to take their music to the next level.",
        "An amazing experience learning here! Pranav and Prayag are are amazing people to work with and learn from! With their vast gig experience and industry standard equipment, there's nothing you can't learn here as a DJ or a producer.",
        "Excellent experience studying here. The quality of music eduction provided here world class and has helped me go along way with my music knowledge and skills.",
        "Really enjoyed the time spent here, learned Djing at the studio and have been using the online platform since a few months now. I would really suggest the in person experience of any course that suits you and the online platform for students outside of Mumbai.",
        "Lost Stories Academy is the best in the music industry to learn music production and DJing. The environment is also friendly the teaching staff is also nice. If anyone wants to persue career in music Lost Stories Academy is the best platform.",
        "The experience has been amazing. The sessions and teachings were very informative and if you're looking to get a kickstart or you want to make it as a full-time thing, LSA has the best of the opportunities and mentors who guide you through all aspects required!.",
        "I’m glad that my search for a music school came to an end here at LSA, i’m having a great time since the time i have joined in. I like the vibe too. I really like the way people are out here. Education is nice too. LSA is not only about music, they also organise play-dates that adds on to my fun. Just got good things to say and share. Apt place for people who want to learn music production & DJing and lets not forget that we’re being trained by someone who’s been playing at the world’s most popular festivals and clubs.",
        "So this was the first time I was entering the music world with 0 knowledge about anything related to music, the beat, the tone, the ups and downs, the velocity control etc etc. But after join this course I got to learn so much and today I have started making my own stuff with much much better knowledge.Thank You Lost Stories Academy for providing such a platform to learn thing in such a comfortable way.",
        "The best place to learn to music production in India and in depth teaching of advanced mixing and mastering concepts. The faculties are very patient and supportive and answer to all the questions asked.",
        "If you are beginning with music production or you are at advance level this is the best academy India for music production. All access pass is total value for money. My quality of production improved a lot in just one month. Thank you Prayag sir for this.",
        "I went in for a beginner's course to learn the basics of music production, I now have the set of skills to start making my own tracks and also have a strong grasp on the fundamentals of sound and music. In hindsight I should've gone in for the Gold since theres so much more value in that course. I'd probably continue my education after taking a break for a bit.",
        "It was a really good experience learning Music production at the academy every module was taught with great depth and helped me gain so much knowledge about how the music industry works Highly recommend for everyone wanting to get into music.",
        "A great place to learn anything and everything related to music. The constant support from the faculty helped me achieve exponential growth in music production, sound design, understanding music theory, mixing and mastering, DJing, etc. which I would not have achieved otherwise. Highly recommend.",
        "Great experience, teacher are amazing and friendly environment. If someone wants to pursue music as an career then I'll suggest you take a look on lost stories academy.",
        "LSA has provided immense support throughout for each of our individual endeavours. The course provides an overall view on the music industry which gives us a really good perspective and scope of it. An amazing journey!!",
        
    ]
}

data = []

for business, texts in reviews.items():
    for text in texts:
        polarity = TextBlob(text).sentiment.polarity
        if polarity > 0.1:
            sentiment = "Positive"
        elif polarity < -0.1:
            sentiment = "Negative"
        else:
            sentiment = "Neutral"
        data.append([business, text, polarity, sentiment])

df = pd.DataFrame(data, columns=["Business", "Review", "Polarity", "Sentiment"])


df.to_csv("sentiment_analysis_results.csv", index=False)
print("✅ Results saved to sentiment_analysis_results.csv")

summary = df.groupby(["Business", "Sentiment"]).size().unstack(fill_value=0)
print("\n--- Sentiment Summary ---")
print(summary)

for business in reviews.keys():
    counts = df[df["Business"] == business]["Sentiment"].value_counts()
    plt.figure(figsize=(5, 5))
    plt.pie(counts, labels=counts.index, autopct="%1.1f%%", startangle=140)
    plt.title(f"Sentiment Distribution - {business}")
    plt.show()

plt.figure(figsize=(7, 5))
df["Sentiment"].value_counts().plot(kind="bar")
plt.title("Overall Sentiment Distribution")
plt.xlabel("Sentiment")
plt.ylabel("Number of Reviews")
plt.show()
# Out:
# ✅ Results saved to sentiment_analysis_results.csv
#
# --- Sentiment Summary ---
# Sentiment             Neutral  Positive
# Business
# Lost Stories Academy        1        21
